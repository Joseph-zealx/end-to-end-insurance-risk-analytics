# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.set(style='whitegrid')

# %%
file_path = "/end-to-end-insurance-risk-analytics/MachineLearningRating_v3.txt"

# %%
df = pd.read_txt(file_path, sep='\t')
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_txt(file_path, sep='\t')
#       2 df.head()
#
# AttributeError: module 'pandas' has no attribute 'read_txt'
